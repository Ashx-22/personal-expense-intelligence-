# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashx-22/personal-expense-intelligence-/blob/main/01_expense_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.2.3

# %%
import os

print(os.listdir("../data/raw"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2624/392231847.py in <cell line: 0>()
#       1 import os
#       2
# ----> 3 print(os.listdir("../data/raw"))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/raw'
